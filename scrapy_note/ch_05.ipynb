# %% [markdown]
# # Ch.05 Scrapy ShellとXPath
#
# - <https://sugiaki1989.gitbook.io/scrapy-note/chapter05_xpath>
# - [クローラ作成に必須！XPATHの記法まとめ](https://qiita.com/rllllho/items/cb1187cec0fb17fc650a)

# %% [markdown]
# |XPath|内容|
# |:-|:-|
# |`.`|カレントノード|
# |`//*`|すべての要素を選択|
# |`.//`|カレントノードから開始する要素を選択|
# |`@`|属性を指定する場合に使用|
# |`.//div`|カレントノードの下のdiv要素を選択|
# |`.//li[a]`|カレントノードの下のli要素を含むa要素を選択|
# |`.//div[@class="quotes"]`|カレントノードの下のdiv要素のクラス属性がquoteを選択|
# |`.//*[text()"Next"]`|Nextという文字列を選択|
# |`//a[contains(text(), "Next")]`|Nextという文字列を含むa要素を選択|
# |`.//*[contains(@class, "Next")]`|Nextという文字列を含むクラス属性を選択|
# |`//h1/following-sibling::p[1]`|h1要素の下の1番目の要素を選択|

# %% [markdown]
# ```bash
# $ scrapy shell "https://www.freeformatter.com/xpath-tester.html"
# 2023-06-26 22:09:07 [scrapy.utils.log] INFO: Scrapy 2.9.0 started (bot: scrapybot)
# 2023-06-26 22:09:07 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.10.11 (main, Apr 24 2023, 17:34:58) [Clang 14.0.3 (clang-1403.0.22.14.1)], pyOpenSSL 23.2.0 (OpenSSL 3.1.1 30 May 2023), cryptography 41.0.1, Platform macOS-13.4-x86_64-i386-64bit
# 2023-06-26 22:09:07 [scrapy.crawler] INFO: Overridden settings:
# {'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0}
# 2023-06-26 22:09:07 [py.warnings] WARNING: /Users/takeru/@LEARNING/Python/scrapy_docs/venv/lib/python3.10/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-06-26 22:09:07 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-06-26 22:09:07 [scrapy.extensions.telnet] INFO: Telnet Password: 9393d85c214afa52
# 2023-06-26 22:09:08 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage']
# 2023-06-26 22:09:08 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-06-26 22:09:08 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-06-26 22:09:08 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-06-26 22:09:08 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-06-26 22:09:08 [scrapy.core.engine] INFO: Spider opened
# 2023-06-26 22:09:08 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): publicsuffix.org:443
# 2023-06-26 22:09:08 [urllib3.connectionpool] DEBUG: https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/1.1" 200 79046
# 2023-06-26 22:09:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.freeformatter.com/xpath-tester.html> (referer: None)
# [s] Available Scrapy objects:
# [s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
# [s]   crawler    <scrapy.crawler.Crawler object at 0x112bcf730>
# [s]   item       {}
# [s]   request    <GET https://www.freeformatter.com/xpath-tester.html>
# [s]   response   <200 https://www.freeformatter.com/xpath-tester.html>
# [s]   settings   <scrapy.settings.Settings object at 0x112bcf610>
# [s]   spider     <DefaultSpider 'default' at 0x11308ca60>
# [s] Useful shortcuts:
# [s]   fetch(url[, redirect=True]) Fetch URL and update local objects (by default, redirects are followed)
# [s]   fetch(req)                  Fetch a scrapy.Request and update local objects
# [s]   shelp()           Shell help (print this help)
# [s]   view(response)    View response in a browser
# ```

# %% [markdown]
# //*[@id="layout-wrapper"]/div[2]/div/div/div[1]/div/div/h1
#
# ```bash
# >>> response.xpath('//*[@id="layout-wrapper"]/div[2]/div/div/div[1]/div/div/h1/text()').get()
# 'XPath Tester - Evaluator'
# ```

# %% [markdown]
# ## Scrapy Shell でXPathを理解する
#
# [Books to Scrapy](https://books.toscrape.com/)

# %% [markdown]
# ```bash
# scrapy shell 'https://books.toscrape.com/'
# ```

# %% [markdown]
# ```bash
# $ scrapy shell 'https://books.toscrape.com/'
# 2023-06-27 21:13:30 [scrapy.utils.log] INFO: Scrapy 2.9.0 started (bot: scrapybot)
# 2023-06-27 21:13:30 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.10.11 (main, Apr 24 2023, 17:34:58) [Clang 14.0.3 (clang-1403.0.22.14.1)], pyOpenSSL 23.2.0 (OpenSSL 3.1.1 30 May 2023), cryptography 41.0.1, Platform macOS-13.4-x86_64-i386-64bit
# 2023-06-27 21:13:30 [scrapy.crawler] INFO: Overridden settings:
# {'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0}
# 2023-06-27 21:13:30 [py.warnings] WARNING: /Users/takeru/@LEARNING/Python/scrapy_docs/venv/lib/python3.10/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-06-27 21:13:30 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-06-27 21:13:30 [scrapy.extensions.telnet] INFO: Telnet Password: b45e83a7a2162c26
# 2023-06-27 21:13:30 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage']
# 2023-06-27 21:13:30 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-06-27 21:13:30 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-06-27 21:13:30 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-06-27 21:13:30 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-06-27 21:13:30 [scrapy.core.engine] INFO: Spider opened
# 2023-06-27 21:13:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://books.toscrape.com/> (referer: None)
# [s] Available Scrapy objects:
# [s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
# [s]   crawler    <scrapy.crawler.Crawler object at 0x1044a3700>
# [s]   item       {}
# [s]   request    <GET https://books.toscrape.com/>
# [s]   response   <200 https://books.toscrape.com/>
# [s]   settings   <scrapy.settings.Settings object at 0x1044a35e0>
# [s]   spider     <DefaultSpider 'default' at 0x1049844f0>
# [s] Useful shortcuts:
# [s]   fetch(url[, redirect=True]) Fetch URL and update local objects (by default, redirects are followed)
# [s]   fetch(req)                  Fetch a scrapy.Request and update local objects
# [s]   shelp()           Shell help (print this help)
# [s]   view(response)    View response in a browser
# ```

# %% [markdown]
# ### タイトル
#
# - //*[@id="default"]/header/div/div/div/a
# - //*[@id="default"]/header/div/div/div/small
#
# ```bash
# >>> response.xpath('//*[@id="default"]/header/div/div/div/a/text()').get()
# 'Books to Scrape'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="col-sm-8 h1"]/a/text()').get()
# 'Books to Scrape'
# ```
#
# ```bash
# >>> response.xpath('//*[@id="default"]/header/div/div/div/small/text()').get()
# ' We love being scraped!'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="col-sm-8 h1"]/small/text()').get()
# ' We love being scraped!'
# ```

# %% [markdown]
# ### Homeボタン
#
# - //*[@id="default"]/div[1]/div/ul/li[1]/a
#
# ```bash
# >>> response.xpath('//*[@id="default"]/div[1]/div/ul/li[1]/a/text()').get()
# 'Home'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="breadcrumb"]/li/a/text()').get()
# 'Home'
# ```
#
# ```bash
# >>> response.xpath('//*[@id="default"]/div[1]/div/ul/li[1]/a/@href').get()
# 'index.html'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="breadcrumb"]/li/a/@href').get()
# 'index.html'
# ```

# %% [markdown]
# ### Homeボタン横の文字列
#
# - //*[@id="default"]/div[1]/div/ul/li[2]
#
# ```bash
# >>> response.xpath('//*[@id="default"]/div[1]/div/ul/li[2]/text()').get()
# 'All products'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="active"]/text()').get()
# 'All products'
# ```

# %% [markdown]
# ### ナビゲーションのタイトル
#
# - //*[@id="default"]/div[1]/div/div/aside/div[2]/ul/li/a
#
# ```bash
# >>> str = response.xpath('//*[@id="default"]/div[1]/div/div/aside/div[2]/ul/li/a/text()').get()
# >>> print(str.replace(" ", "").replace("\n", ""))
# Books
# ```
#
# ```bash
# >>> str = response.xpath('//*[@class="nav nav-list"]/li/a/text()').get()
# >>> print(str.replace(" ", "").replace("\n", ""))
# Books
# ```
#
# ```bash
# >>> response.xpath('//*[@class="nav nav-list"]/li/a/@href').get()
# 'catalogue/category/books_1/index.html'
# ```

# %% [markdown]
# ### ナビゲーションのリスト
#
# - //*[@id="default"]/div[1]/div/div/aside/div[2]/ul/li/ul/li/a
# - //*[@id="default"]/div[1]/div/div/aside/div[2]/ul/li/ul/li[1]/a
# - //*[@id="default"]/div[1]/div/div/aside/div[2]/ul/li/ul/li[2]/a
#
# ```bash
# >>> response.xpath('//*[@id="default"]/div[1]/div/div/aside/div[2]/ul/li/ul/li/a/@href').getall()
# ['catalogue/category/books/travel_2/index.html', 'catalogue/category/books/mystery_3/index.html', 'catalogue/category/books/historical-fiction_4/index.html', 'catalogue/category/books/sequential-art_5/index.html', 'catalogue/category/books/classics_6/index.html', 'catalogue/category/books/philosophy_7/index.html', 'catalogue/category/books/romance_8/index.html', 'catalogue/category/books/womens-fiction_9/index.html', 'catalogue/category/books/fiction_10/index.html', 'catalogue/category/books/childrens_11/index.html', 'catalogue/category/books/religion_12/index.html', 'catalogue/category/books/nonfiction_13/index.html', 'catalogue/category/books/music_14/index.html', 'catalogue/category/books/default_15/index.html', 'catalogue/category/books/science-fiction_16/index.html', 'catalogue/category/books/sports-and-games_17/index.html', 'catalogue/category/books/add-a-comment_18/index.html', 'catalogue/category/books/fantasy_19/index.html', 'catalogue/category/books/new-adult_20/index.html', 'catalogue/category/books/young-adult_21/index.html', 'catalogue/category/books/science_22/index.html', 'catalogue/category/books/poetry_23/index.html', 'catalogue/category/books/paranormal_24/index.html', 'catalogue/category/books/art_25/index.html', 'catalogue/category/books/psychology_26/index.html', 'catalogue/category/books/autobiography_27/index.html', 'catalogue/category/books/parenting_28/index.html', 'catalogue/category/books/adult-fiction_29/index.html', 'catalogue/category/books/humor_30/index.html', 'catalogue/category/books/horror_31/index.html', 'catalogue/category/books/history_32/index.html', 'catalogue/category/books/food-and-drink_33/index.html', 'catalogue/category/books/christian-fiction_34/index.html', 'catalogue/category/books/business_35/index.html', 'catalogue/category/books/biography_36/index.html', 'catalogue/category/books/thriller_37/index.html', 'catalogue/category/books/contemporary_38/index.html', 'catalogue/category/books/spirituality_39/index.html', 'catalogue/category/books/academic_40/index.html', 'catalogue/category/books/self-help_41/index.html', 'catalogue/category/books/historical_42/index.html', 'catalogue/category/books/christian_43/index.html', 'catalogue/category/books/suspense_44/index.html', 'catalogue/category/books/short-stories_45/index.html', 'catalogue/category/books/novels_46/index.html', 'catalogue/category/books/health_47/index.html', 'catalogue/category/books/politics_48/index.html', 'catalogue/category/books/cultural_49/index.html', 'catalogue/category/books/erotica_50/index.html', 'catalogue/category/books/crime_51/index.html']
# ```
#
# ```bash
# >>> response.xpath('//*[@class="side_categories"]/ul/li/ul/li/a/@href').getall()
# ['catalogue/category/books/travel_2/index.html', 'catalogue/category/books/mystery_3/index.html', 'catalogue/category/books/historical-fiction_4/index.html', 'catalogue/category/books/sequential-art_5/index.html', 'catalogue/category/books/classics_6/index.html', 'catalogue/category/books/philosophy_7/index.html', 'catalogue/category/books/romance_8/index.html', 'catalogue/category/books/womens-fiction_9/index.html', 'catalogue/category/books/fiction_10/index.html', 'catalogue/category/books/childrens_11/index.html', 'catalogue/category/books/religion_12/index.html', 'catalogue/category/books/nonfiction_13/index.html', 'catalogue/category/books/music_14/index.html', 'catalogue/category/books/default_15/index.html', 'catalogue/category/books/science-fiction_16/index.html', 'catalogue/category/books/sports-and-games_17/index.html', 'catalogue/category/books/add-a-comment_18/index.html', 'catalogue/category/books/fantasy_19/index.html', 'catalogue/category/books/new-adult_20/index.html', 'catalogue/category/books/young-adult_21/index.html', 'catalogue/category/books/science_22/index.html', 'catalogue/category/books/poetry_23/index.html', 'catalogue/category/books/paranormal_24/index.html', 'catalogue/category/books/art_25/index.html', 'catalogue/category/books/psychology_26/index.html', 'catalogue/category/books/autobiography_27/index.html', 'catalogue/category/books/parenting_28/index.html', 'catalogue/category/books/adult-fiction_29/index.html', 'catalogue/category/books/humor_30/index.html', 'catalogue/category/books/horror_31/index.html', 'catalogue/category/books/history_32/index.html', 'catalogue/category/books/food-and-drink_33/index.html', 'catalogue/category/books/christian-fiction_34/index.html', 'catalogue/category/books/business_35/index.html', 'catalogue/category/books/biography_36/index.html', 'catalogue/category/books/thriller_37/index.html', 'catalogue/category/books/contemporary_38/index.html', 'catalogue/category/books/spirituality_39/index.html', 'catalogue/category/books/academic_40/index.html', 'catalogue/category/books/self-help_41/index.html', 'catalogue/category/books/historical_42/index.html', 'catalogue/category/books/christian_43/index.html', 'catalogue/category/books/suspense_44/index.html', 'catalogue/category/books/short-stories_45/index.html', 'catalogue/category/books/novels_46/index.html', 'catalogue/category/books/health_47/index.html', 'catalogue/category/books/politics_48/index.html', 'catalogue/category/books/cultural_49/index.html', 'catalogue/category/books/erotica_50/index.html', 'catalogue/category/books/crime_51/index.html']
# ```

# %% [markdown]
# ```bash
# >>> strings = response.xpath('//*[@class="side_categories"]/ul/li/ul/li/a/text()').getall()
# >>> list = []
# >>> for string in strings:
# ...     string = string.replace(' ', '')
# ...     string = string.replace('\n', '')
# ...     list.append(string)
# ...
# >>> print(list)
# ['Travel', 'Mystery', 'HistoricalFiction', 'SequentialArt', 'Classics', 'Philosophy', 'Romance', 'WomensFiction', 'Fiction', 'Childrens', 'Religion', 'Nonfiction', 'Music', 'Default', 'ScienceFiction', 'SportsandGames', 'Addacomment', 'Fantasy', 'NewAdult', 'YoungAdult', 'Science', 'Poetry', 'Paranormal', 'Art', 'Psychology', 'Autobiography', 'Parenting', 'AdultFiction', 'Humor', 'Horror', 'History', 'FoodandDrink', 'ChristianFiction', 'Business', 'Biography', 'Thriller', 'Contemporary', 'Spirituality', 'Academic', 'SelfHelp', 'Historical', 'Christian', 'Suspense', 'ShortStories', 'Novels', 'Health', 'Politics', 'Cultural', 'Erotica', 'Crime']
# ```

# %% [markdown]
# ### 書籍一覧のタイトル
#
# - //*[@id="default"]/div[1]/div/div/div/div[1]/h1
#
# ```bash
# >>> response.xpath('//*[@id="default"]/div[1]/div/div/div/div[1]/h1/text()').get()
# 'All products'
# ```
#
# ```bash
# >>> response.xpath('//h1/text()').get()
# 'All products'
# ```

# %% [markdown]
# ### ページャの部分
#
# - //*[@id="default"]/div[1]/div/div/div/form
# - //*[@class="form-horizontal"]/strong
# - //*[@class="form-horizontal"]/strong/following-sibling::text()
#
# ```bash
# >>> response.xpath('//*[@class="form-horizontal"]/strong/text()').getall()
# ['1000', '1', '20']
# ```
#
# ```bash
# >>> response.xpath('//*[@class="form-horizontal"]/strong/following-sibling::text()').getall()
# [' results - showing ', ' to ', '.\n                \n            \n            \n        \n    ']
# ```

# %% [markdown]
# ### ワーニングの部分
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[1]/strong
# - //*[@id="default"]/div[1]/div/div/div/section/div[1]
#
# ```bash
# >>> response.xpath('//*[@class="alert alert-warning"]/strong/text()').get()
# 'Warning!'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="alert alert-warning"]/text()').get()
# ' This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.'
# ```

# %% [markdown]
# ### 書籍の画像のURL
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[2]/ol/li[1]/article/div[1]/a/img
# - //*[@class="image_container"]/a/@href'
#
# ```bash
# >>> response.xpath('//*[@class="image_container"]/a/@href').getall()
# ['catalogue/a-light-in-the-attic_1000/index.html', 'catalogue/tipping-the-velvet_999/index.html', 'catalogue/soumission_998/index.html', 'catalogue/sharp-objects_997/index.html', 'catalogue/sapiens-a-brief-history-of-humankind_996/index.html', 'catalogue/the-requiem-red_995/index.html', 'catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html', 'catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html', 'catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html', 'catalogue/the-black-maria_991/index.html', 'catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html', 'catalogue/shakespeares-sonnets_989/index.html', 'catalogue/set-me-free_988/index.html', 'catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html', 'catalogue/rip-it-up-and-start-again_986/index.html', 'catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html', 'catalogue/olio_984/index.html', 'catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html', 'catalogue/libertarianism-for-beginners_982/index.html', 'catalogue/its-only-the-himalayas_981/index.html']
# ```

# %% [markdown]
# ### 書籍のタイトル
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[2]/ol/li[1]/article/h3/a
# - '//h3/a/text()'
#
# ```bash
# >>> response.xpath('//h3/a/text()').getall()
# ['A Light in the ...', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History ...', 'The Requiem Red', 'The Dirty Little Secrets ...', 'The Coming Woman: A ...', 'The Boys in the ...', 'The Black Maria', 'Starving Hearts (Triangular Trade ...', "Shakespeare's Sonnets", 'Set Me Free', "Scott Pilgrim's Precious Little ...", 'Rip it Up and ...', 'Our Band Could Be ...', 'Olio', 'Mesaerion: The Best Science ...', 'Libertarianism for Beginners', "It's Only the Himalayas"]
# ```

# %% [markdown]
# ### レビューの星
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[2]/ol/li[1]/article/p
# - //*[contains(@class, "star-rating")]/@class
#
# ```bash
# >>> response.xpath('//*[contains(@class, "star-rating")]/@class').getall()
# ['star-rating Three', 'star-rating One', 'star-rating One', 'star-rating Four', 'star-rating Five', 'star-rating One', 'star-rating Four', 'star-rating Three', 'star-rating Four', 'star-rating One', 'star-rating Two', 'star-rating Four', 'star-rating Five', 'star-rating Five', 'star-rating Five', 'star-rating Three', 'star-rating One', 'star-rating One', 'star-rating Two', 'star-rating Two']
# ```

# %% [markdown]
# ### 書籍の金額
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[2]/ol/li[2]/article/div[2]/p[1]
# - //*[@class="price_color"]/text()
#
# ```bash
# >>> response.xpath('//*[@class="price_color"]/text()').getall()
# ['£51.77', '£53.74', '£50.10', '£47.82', '£54.23', '£22.65', '£33.34', '£17.93', '£22.60', '£52.15', '£13.99', '£20.66', '£17.46', '£52.29', '£35.02', '£57.25', '£23.88', '£37.59', '£51.33', '£45.17']
# ```

# %% [markdown]
# ### 書籍の在庫ステータス（In stock）
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[2]/ol/li[1]/article/div[2]/p[2]/i
# - //*[@class="instock availability"]/text()
#
# ```bash
# >>> response.xpath('//*[@class="instock availability"]/text()').getall()
# ['\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n', '\n    ', '\n    \n        In stock\n    \n']
# ```

# %% [markdown]
# ```bash
# >>> response.xpath('//*[@class="icon-ok"]/following-sibling::text()').getall()
# ['\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n', '\n    \n        In stock\n    \n']
# ```

# %% [markdown]
# ### カートに入れるボタン
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[2]/ol/li[1]/article/div[2]/form/button
# - //*[@class="btn btn-primary btn-block"]/text()
#
# ```bash
# >>> response.xpath('//*[@class="btn btn-primary btn-block"]/text()').getall()
# ['Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket', 'Add to basket']
# ```

# %% [markdown]
# ### １番下のページャ
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[2]/div/ul/li[1]
# - //*[@class="current"]/text()
#
# ```bash
# >>> response.xpath('//*[@class="current"]/text()').get()
# '\n            \n                Page 1 of 50\n            \n            '
# ```

# %% [markdown]
# ### １番下のNextボタン
#
# - //*[@id="default"]/div[1]/div/div/div/section/div[2]/div/ul/li[2]/a
# - //*[@class="next"]/a/@href
#
# ```bash
# >>> response.xpath('//*[@class="next"]/a/@href').get()
# 'catalogue/page-2.html'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="next"]/a/text()').get()
# 'next'
# ```

# %% [markdown]
# ### 書籍の詳細ページ
#
# - <http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html>
#
# ```bash
# scrapy shell 'http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'
# 2023-06-30 19:31:53 [scrapy.utils.log] INFO: Scrapy 2.9.0 started (bot: scrapybot)
# 2023-06-30 19:31:53 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.10.11 (main, Apr 24 2023, 17:34:58) [Clang 14.0.3 (clang-1403.0.22.14.1)], pyOpenSSL 23.2.0 (OpenSSL 3.1.1 30 May 2023), cryptography 41.0.1, Platform macOS-13.4-x86_64-i386-64bit
# 2023-06-30 19:31:53 [scrapy.crawler] INFO: Overridden settings:
# {'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0}
# 2023-06-30 19:31:53 [py.warnings] WARNING: /Users/takeru/@LEARNING/Python/scrapy_docs/venv/lib/python3.10/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-06-30 19:31:53 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-06-30 19:31:53 [scrapy.extensions.telnet] INFO: Telnet Password: 9a5cf274348f6321
# 2023-06-30 19:31:53 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage']
# 2023-06-30 19:31:53 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-06-30 19:31:53 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-06-30 19:31:53 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-06-30 19:31:53 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-06-30 19:31:53 [scrapy.core.engine] INFO: Spider opened
# 2023-06-30 19:31:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html> (referer: None)
# [s] Available Scrapy objects:
# [s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
# [s]   crawler    <scrapy.crawler.Crawler object at 0x1131ef730>
# [s]   item       {}
# [s]   request    <GET http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html>
# [s]   response   <200 http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html>
# [s]   settings   <scrapy.settings.Settings object at 0x1131ef070>
# [s]   spider     <DefaultSpider 'default' at 0x1136cc580>
# [s] Useful shortcuts:
# [s]   fetch(url[, redirect=True]) Fetch URL and update local objects (by default, redirects are followed)
# [s]   fetch(req)                  Fetch a scrapy.Request and update local objects
# [s]   shelp()           Shell help (print this help)
# [s]   view(response)    View response in a browser
# ```

# %% [markdown]
# ### パンくずリストの商品名
#
# - //*[@id="default"]/div[1]/div/ul
# - //*[@class="breadcrumb"]/li/a/text()
#
# ```bash
# >>> response.xpath('//*[@class="breadcrumb"]/li/a/text()').getall()
# ['Home', 'Books', 'Poetry']
# ```
#
# ```bash
# >>> response.xpath('//*[@class="active"]/text()').get()
# 'A Light in the Attic'
# ```

# %% [markdown]
# ### 商品名、金額、在庫、レビューの星の数
#
# - 商品名
#   - //*[@id="content_inner"]/article/div[1]/div[2]/h1
#   - //h1/text()
# - 金額
#   - //*[@id="content_inner"]/article/div[1]/div[2]/p[1]
#   - //*[@class="price_color"]/text()
# - 在庫
#   - //*[@id="content_inner"]/article/div[1]/div[2]/p[2]
#   - //*[@class="instock availability"]/i/following-sibling::text()
# - レビューの星の数
#   - //*[@id="content_inner"]/article/div[1]/div[2]/p[3]
#   - //*[contains(@class, "star-rating")]/@class
#
# ```bash
# >>> response.xpath('//h1/text()').get()
# 'A Light in the Attic'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="price_color"]/text()').get()
# '£51.77'
# ```
#
# ```bash
# >>> response.xpath('//*[@class="instock availability"]/i/following-sibling::text()').get()
# '\n    \n        In stock (22 available)\n    \n'
# ```
#
# ```bash
# >>> response.xpath('//*[contains(@class, "star-rating")]/@class').get()
# 'star-rating Three'
# ```

# %% [markdown]
# ### 説明文のタイトルと説明文
#
# - 説明文のタイトル
#   - //*[@id="product_description"]/h2
#   - //h2/text()
# - 説明文
#   - //*[@id="content_inner"]/article/p
#   - //*[@id="product_description"]/following-sibling::p/text()
#
# ```bash
# >>> response.xpath('//h2/text()').get()
# 'Product Description'
# ```
#
# ```bash
# >>> response.xpath('//*[@id="product_description"]/following-sibling::p/text()').get()
# "It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love th It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love that Silverstein. Need proof of his genius? RockabyeRockabye baby, in the treetopDon't you know a treetopIs no safe place to rock?And who put you up there,And your cradle, too?Baby, I think someone down here'sGot it in for you. Shel, you never sounded so good. ...more"
# ```

# %% [markdown]
# ### 商品情報の一覧
#
# - UPC
#   - //*[@id="content_inner"]/article/table/tbody/tr[1]/td
#   - //th[text()="UPC"]/following-sibling::td/text()
# - Product Type
#   - //*[@id="content_inner"]/article/table/tbody/tr[2]/td
#   - //th[text()="Product Type"]/following-sibling::td/text()
# - Price (excl. tax)
#   - //*[@id="content_inner"]/article/table/tbody/tr[3]/td
#   - //th[text()="Price (excl. tax)"]/following-sibling::td/text()
# - Price (incl. tax)
#   - //*[@id="content_inner"]/article/table/tbody/tr[4]/td
#   - //th[text()="Price (incl. tax)"]/following-sibling::td/text()
# - Tax
#   - //*[@id="content_inner"]/article/table/tbody/tr[5]/td
#   - //th[text()="Tax"]/following-sibling::td/text()
# - Availability
#   - //*[@id="content_inner"]/article/table/tbody/tr[6]/td
#   - //th[text()="Availability"]/following-sibling::td/text()
# - Number of reviews
#   - //*[@id="content_inner"]/article/table/tbody/tr[7]/td
#   - //th[text()="Number of reviews"]/following-sibling::td/text()
#
# ```bash
# >>> response.xpath('//th[text()="UPC"]/following-sibling::td/text()').get()
# 'a897fe39b1053632'
# ```
#
# ```bash
# >>> response.xpath('//th[text()="Product Type"]/following-sibling::td/text()').get()
# 'Books'
# ```
#
# ```bash
# >>> response.xpath('//th[text()="Price (excl. tax)"]/following-sibling::td/text()').get()
# '£51.77'
# ```
#
# ```bash
# >>> response.xpath('//th[text()="Price (incl. tax)"]/following-sibling::td/text()').get()
# '£51.77'
# ```
#
# ```bash
# >>> response.xpath('//th[text()="Tax"]/following-sibling::td/text()').get()
# '£0.00'
# ```
#
# ```bash
# >>> response.xpath('//th[text()="Availability"]/following-sibling::td/text()').get()
# 'In stock (22 available)'
# ```
#
# ```bash
# >>> response.xpath('//th[text()="Number of reviews"]/following-sibling::td/text()').get()
# '0'
# ```

# %% [markdown]
# ```bash
# >>> def table_info(response, name):
# ...     return response.xpath('//th[text()="' + name + '"]/following-sibling::td/text()').get()
# ...
# >>> table_info(response, "UPC")
# 'a897fe39b1053632'
# >>>
# >>> table_info(response, "Product Type")
# 'Books'
# >>>
# >>> table_info(response, "Price (excl. tax)")
# '£51.77'
# >>>
# >>> table_info(response, "Price (incl. tax)")
# '£51.77'
# >>>
# >>> table_info(response, "Tax")
# '£0.00'
# >>>
# >>> table_info(response, "Availability")
# 'In stock (22 available)'
# >>>
# >>> table_info(response, "Number of reviews")
# '0'
# ```
